# %% [markdown]
# # Install Library, if necessary

# %%
Install Library if necessary
! pip install pymongo

# %% [markdown]
# # Import main mongo class

# %%
from pymongo import MongoClient

# %% [markdown]
# # Connect to mongo database

# %%
# Make sure to set up login and pw - DO NOT USE AN OPEN DB
client = MongoClient("localhost", 27017)

# %%
from pymongo import MongoClient
import urllib.parse

username = "your_username"
password = "your_password" # If your password contains special characters like '@' or '/', it needs to be URL-encoded.
# Example for encoding:
# password = urllib.parse.quote_plus("pass/word")

client = MongoClient(f"mongodb://{username}:{password}@localhost:27017/your_database")

# %% [markdown]
# # List current databases in mongo

# %%
dbs = client.list_database_names()
print(dbs)
# Out:
# ['admin', 'config', 'local', 'messages', 'mydatabase']

# %% [markdown]
# # Add content (and a new database and collection)

# %%
mydb = client["mydatabase"]
mycol = mydb["mycol"]

myentry = { "name": "John", "address": "Highway 37" }

x = mycol.insert_one(myentry)

# %% [markdown]
# # Query for content

# %%
myquery = { "name": "John" }

mydoc = mycol.find(myquery)

for rec in mydoc:
    print( rec)
# Out:
# {'_id': ObjectId('68ebb20a3dd4a64091815bc5'), 'name': 'John', 'address': 'Highway 37'}
